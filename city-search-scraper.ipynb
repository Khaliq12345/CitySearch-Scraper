# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
response = requests.get('https://api.citygridmedia.com/content/places/v2/search/where?what=Appliance%20Repair&where=Los,Angeles&publisher=citysearch&format=json&placement=loki&page=26&rpp=100')
data = response.json()

if data['results']['last_hit'] < data['results']['total_hits']:
    print('Yes')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [2], line 4
#       1 response = requests.get('https://api.citygridmedia.com/content/places/v2/search/where?what=Appliance%20Repair&where=Los,Angeles&publisher=citysearch&format=json&placement=loki&page=26&rpp=100')
#       2 data = response.json()
# ----> 4 if data['results']['last_hit'] < data['results']['total_hits']:
#       5     print('Yes')
#
# KeyError: 'results'

# %%
data
# Out:
# {'results': {'uri': 'http://api.citygridmedia.com/search/real/where?what=Appliance%20Repair&where=Los,Angeles&publisher=citysearch&format=json&placement=loki&page=1&rpp=100',
#   'first_hit': 1,
#   'last_hit': 100,
#   'total_hits': 3504,
#   'page': 1,
#   'rpp': 100,
#   'regions': [{'type': 'city',
#     'name': 'Los Angeles',
#     'latitude': 34.10652,
#     'longitude': -118.411509,
#     'default_radius': 22.45}],
#   'geo_ids': [56050],
#   'tag_ids': [11440,
#    11456,
#    11457,
#    11442,
#    11446,
#    11451,
#    11452,
#    11453,
#    11454,
#    11455],
#   'locations': [{'id': 689953046,
#     'featured': False,
#     'name': 'TJ Appliance Repair',
#     'address': {'street': '7608 Santa Monica Blvd',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'postal_code': '90046'},
#     'neighborhood': 'West Hollywood',
#     'latitude': 34.090684,
#     'longitude': -118.355516,
#     'phone_number': '8186147700',
#     'rating': 0.0,
# ...

# %%
name = data['results']['locations'][0]['name']
street = data['results']['locations'][0]['address']['street']
city = data['results']['locations'][0]['address']['city']
state = data['results']['locations'][0]['address']['state']
postal_code = data['results']['locations'][0]['address']['postal_code']
phone = data['results']['locations'][0]['phone_number']
rating = data['results']['locations'][0]['rating']
profile = data['results']['locations'][0]['profile']
review = data['results']['locations'][0]['user_review_count']
categories = data['results']['locations'][0]['sample_categories']

# %% [markdown]
# ## Thank you

# %%
isNext = True
n = 1
while isNext:
    try:
        response = requests.get(f'https://api.citygridmedia.com/content/places/v2/search/where?what=Appliance%20Repair&where=Los,Angeles&publisher=citysearch&format=json&placement=loki&page={n}&rpp=100')
        data = response.json()
            
        print(f'Page {n}')


        if data['results']['last_hit'] < data['results']['total_hits']:
            n = n + 1
        else:
            isNext = False
            break
    except:
        break
print('We are good')
# Out:
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# Page 11
# Page 12
# Page 13
# Page 14
# Page 15
# Page 16
# Page 17
# Page 18
# Page 19
# Page 20
# Page 21
# Page 22
# Page 23
# Page 24
# We are good
